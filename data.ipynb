# %%
import pandas as pd

# %%
df = pd.read_csv('case_covid_1.csv', index_col='iso_code')
df
# https://ourworldindata.org/covid-cases
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          5.0        5.0
# AFG           Asia  Afghanistan  2020-02-25          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          5.0        0.0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13     231381.0       82.0
# ZWE         Africa     Zimbabwe  2022-02-14     231603.0      222.0
# ZWE         Africa     Zimbabwe  2022-02-15     231603.0        0.0
# ZWE         Africa     Zimbabwe  2022-02-16     232213.0      610.0
# ZWE         Africa     Zimbabwe  2022-02-17     232598.0      385.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
# df[df['continent'].str.contains('asia', case=False)]

# %%
df[df['continent'].isnull()]
# Out:
#          continent location        date  total_cases  new_cases  \
# iso_code
# OWID_AFR       NaN   Africa  2020-02-13          NaN        0.0
# OWID_AFR       NaN   Africa  2020-02-14          1.0        1.0
# OWID_AFR       NaN   Africa  2020-02-15          1.0        0.0
# OWID_AFR       NaN   Africa  2020-02-16          1.0        0.0
# OWID_AFR       NaN   Africa  2020-02-17          1.0        0.0
# ...            ...      ...         ...          ...        ...
# OWID_WRL       NaN    World  2022-02-13  411738105.0  1454191.0
# OWID_WRL       NaN    World  2022-02-14  413526543.0  1788438.0
# OWID_WRL       NaN    World  2022-02-15  415291868.0  1765325.0
# OWID_WRL       NaN    World  2022-02-16  417730572.0  2438704.0
# OWID_WRL       NaN    World  2022-02-17  419693540.0  1962968.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# OWID_AFR                 NaN           NaN         0.0                  NaN
# ...

# %%
dd = df['date'].str.split('-', expand=True)
dd.columns = ['year', 'month', 'date']
dd
# Out:
#           year month date
# iso_code
# AFG       2020    02   24
# AFG       2020    02   25
# AFG       2020    02   26
# AFG       2020    02   27
# AFG       2020    02   28
# ...        ...   ...  ...
# ZWE       2022    02   13
# ZWE       2022    02   14
# ZWE       2022    02   15
# ZWE       2022    02   16
# ZWE       2022    02   17
#
# [162607 rows x 3 columns]

# %%
dd1 = dd[dd.columns[0:2]]
dd1.sample(5)
# Out:
#           year month
# iso_code
# CAN       2022    01
# JAM       2021    08
# LCA       2021    05
# TJK       2021    03
# BGD       2020    03

# %%
df['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
# df[df.iso_code.str.contains('OWID_wrl', case=False)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162607 entries, AFG to ZWE
# Data columns (total 66 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   continent                                   152859 non-null  object
#  1   location                                    162607 non-null  object
#  2   date                                        162607 non-null  object
#  3   total_cases                                 159642 non-null  float64
#  4   new_cases                                   159616 non-null  float64
#  5   new_cases_smoothed                          158465 non-null  float64
#  6   total_deaths                                141946 non-null  float64
#  7   new_deaths                                  142122 non-null  float64
#  8   new_deaths_smoothed                         141992 non-null  float64
# ...

# %%
dp = df.columns[15:67]
df.drop(dp, axis=1, inplace=True)
df
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          5.0        5.0
# AFG           Asia  Afghanistan  2020-02-25          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          5.0        0.0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13     231381.0       82.0
# ZWE         Africa     Zimbabwe  2022-02-14     231603.0      222.0
# ZWE         Africa     Zimbabwe  2022-02-15     231603.0        0.0
# ZWE         Africa     Zimbabwe  2022-02-16     232213.0      610.0
# ZWE         Africa     Zimbabwe  2022-02-17     232598.0      385.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
dt = pd.concat([df, dd1], axis=True)
dt
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          5.0        5.0
# AFG           Asia  Afghanistan  2020-02-25          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          5.0        0.0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13     231381.0       82.0
# ZWE         Africa     Zimbabwe  2022-02-14     231603.0      222.0
# ZWE         Africa     Zimbabwe  2022-02-15     231603.0        0.0
# ZWE         Africa     Zimbabwe  2022-02-16     232213.0      610.0
# ZWE         Africa     Zimbabwe  2022-02-17     232598.0      385.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
dt.dropna(subset=['continent'], inplace=True)
dt
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          5.0        5.0
# AFG           Asia  Afghanistan  2020-02-25          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          5.0        0.0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13     231381.0       82.0
# ZWE         Africa     Zimbabwe  2022-02-14     231603.0      222.0
# ZWE         Africa     Zimbabwe  2022-02-15     231603.0        0.0
# ZWE         Africa     Zimbabwe  2022-02-16     232213.0      610.0
# ZWE         Africa     Zimbabwe  2022-02-17     232598.0      385.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
dg = dt[dt.columns[:6]]
dg
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          5.0        5.0
# AFG           Asia  Afghanistan  2020-02-25          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          5.0        0.0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13     231381.0       82.0
# ZWE         Africa     Zimbabwe  2022-02-14     231603.0      222.0
# ZWE         Africa     Zimbabwe  2022-02-15     231603.0        0.0
# ZWE         Africa     Zimbabwe  2022-02-16     232213.0      610.0
# ZWE         Africa     Zimbabwe  2022-02-17     232598.0      385.0
#
#           new_cases_smoothed
# iso_code
# AFG                      NaN
# AFG                      NaN
# AFG                      NaN
# ...

# %%
dh = dt[dt.columns[15:17]]
dh
# Out:
#           year month
# iso_code
# AFG       2020    02
# AFG       2020    02
# AFG       2020    02
# AFG       2020    02
# AFG       2020    02
# ...        ...   ...
# ZWE       2022    02
# ZWE       2022    02
# ZWE       2022    02
# ZWE       2022    02
# ZWE       2022    02
#
# [152859 rows x 2 columns]

# %%
dy = dt[dt.columns[7:9]]
dy
# Out:
#           new_deaths  new_deaths_smoothed
# iso_code
# AFG              NaN                  NaN
# AFG              NaN                  NaN
# AFG              NaN                  NaN
# AFG              NaN                  NaN
# AFG              NaN                  NaN
# ...              ...                  ...
# ZWE              0.0                1.714
# ZWE              0.0                1.714
# ZWE              0.0                1.143
# ZWE              5.0                1.714
# ZWE              2.0                1.143
#
# [152859 rows x 2 columns]

# %%
dn = pd.concat([dg,dy,dh],axis=True)
dn
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24          5.0        5.0
# AFG           Asia  Afghanistan  2020-02-25          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-26          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-27          5.0        0.0
# AFG           Asia  Afghanistan  2020-02-28          5.0        0.0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13     231381.0       82.0
# ZWE         Africa     Zimbabwe  2022-02-14     231603.0      222.0
# ZWE         Africa     Zimbabwe  2022-02-15     231603.0        0.0
# ZWE         Africa     Zimbabwe  2022-02-16     232213.0      610.0
# ZWE         Africa     Zimbabwe  2022-02-17     232598.0      385.0
#
#           new_cases_smoothed  new_deaths  new_deaths_smoothed  year month
# iso_code
# ...

# %%
# dn['iso_code'].unique()

# %%
dn.loc['THA']
# Out:
#          continent  location        date  total_cases  new_cases  \
# iso_code
# THA           Asia  Thailand  2020-01-04          NaN        NaN
# THA           Asia  Thailand  2020-01-05          NaN        NaN
# THA           Asia  Thailand  2020-01-06          NaN        NaN
# THA           Asia  Thailand  2020-01-07          NaN        NaN
# THA           Asia  Thailand  2020-01-08          NaN        NaN
# ...            ...       ...         ...          ...        ...
# THA           Asia  Thailand  2022-02-13    2608227.0    14900.0
# THA           Asia  Thailand  2022-02-14    2622600.0    14373.0
# THA           Asia  Thailand  2022-02-15    2639062.0    16462.0
# THA           Asia  Thailand  2022-02-16    2656411.0    17349.0
# THA           Asia  Thailand  2022-02-17    2674477.0    18066.0
#
#           new_cases_smoothed  new_deaths  new_deaths_smoothed  year month
# iso_code
# THA                      NaN         NaN                  NaN  2020    01
# ...

# %%
dn['total_cases'] = dn['total_cases'].fillna(0)
dn['new_cases'] = dn['new_cases'].fillna(0)
dn['new_deaths'] = dn['new_deaths'].fillna(0)

# %%
dn['total_cases'] = dn['total_cases'].astype(int)
dn['new_cases'] = dn['new_cases'].astype(int)
dn['new_deaths'] = dn['new_deaths'].astype(int)
dn
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24            5          5
# AFG           Asia  Afghanistan  2020-02-25            5          0
# AFG           Asia  Afghanistan  2020-02-26            5          0
# AFG           Asia  Afghanistan  2020-02-27            5          0
# AFG           Asia  Afghanistan  2020-02-28            5          0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13       231381         82
# ZWE         Africa     Zimbabwe  2022-02-14       231603        222
# ZWE         Africa     Zimbabwe  2022-02-15       231603          0
# ZWE         Africa     Zimbabwe  2022-02-16       232213        610
# ZWE         Africa     Zimbabwe  2022-02-17       232598        385
#
#           new_cases_smoothed  new_deaths  new_deaths_smoothed  year month
# iso_code
# ...

# %%
# df.drop(dp, axis=1, inplace=True)
dn.drop(['new_cases_smoothed','new_deaths_smoothed'], axis=1, inplace=True)
dn
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-02-24            5          5
# AFG           Asia  Afghanistan  2020-02-25            5          0
# AFG           Asia  Afghanistan  2020-02-26            5          0
# AFG           Asia  Afghanistan  2020-02-27            5          0
# AFG           Asia  Afghanistan  2020-02-28            5          0
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-02-13       231381         82
# ZWE         Africa     Zimbabwe  2022-02-14       231603        222
# ZWE         Africa     Zimbabwe  2022-02-15       231603          0
# ZWE         Africa     Zimbabwe  2022-02-16       232213        610
# ZWE         Africa     Zimbabwe  2022-02-17       232598        385
#
#           new_deaths  year month
# iso_code
# AFG                0  2020    02
# AFG                0  2020    02
# ...

# %%
# dn[dn['year'].str.contains(r'2022')]
dn[dn['month'].str.contains(r'01')]
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2021-01-01        52513        183
# AFG           Asia  Afghanistan  2021-01-02        52586         73
# AFG           Asia  Afghanistan  2021-01-03        52709        123
# AFG           Asia  Afghanistan  2021-01-04        52909        200
# AFG           Asia  Afghanistan  2021-01-05        53011        102
# ...            ...          ...         ...          ...        ...
# ZWE         Africa     Zimbabwe  2022-01-27       229096        153
# ZWE         Africa     Zimbabwe  2022-01-28       229333        237
# ZWE         Africa     Zimbabwe  2022-01-29       229415         82
# ZWE         Africa     Zimbabwe  2022-01-30       229460         45
# ZWE         Africa     Zimbabwe  2022-01-31       229666        206
#
#           new_deaths  year month
# iso_code
# AFG               12  2021    01
# AFG               10  2021    01
# ...

# %%
dn[dn['location']=='Thailand']
# Out:
#          continent  location        date  total_cases  new_cases  new_deaths  \
# iso_code
# THA           Asia  Thailand  2020-01-04            0          0           0
# THA           Asia  Thailand  2020-01-05            0          0           0
# THA           Asia  Thailand  2020-01-06            0          0           0
# THA           Asia  Thailand  2020-01-07            0          0           0
# THA           Asia  Thailand  2020-01-08            0          0           0
# ...            ...       ...         ...          ...        ...         ...
# THA           Asia  Thailand  2022-02-13      2608227      14900          26
# THA           Asia  Thailand  2022-02-14      2622600      14373          27
# THA           Asia  Thailand  2022-02-15      2639062      16462          27
# THA           Asia  Thailand  2022-02-16      2656411      17349          22
# THA           Asia  Thailand  2022-02-17      2674477      18066          27
#
#           year month
# iso_code
# ...

# %%
cty = dn[dn['location'].str.contains(r'thai|state|kingdom$|india', case=False)]
# col = ['new_cases','location', 'year']
# dn[col].groupby(['location', 'year']).sum()
cty
# Out:
#               continent       location        date  total_cases  new_cases  \
# iso_code
# IND                Asia          India  2020-01-30            1          1
# IND                Asia          India  2020-01-31            1          0
# IND                Asia          India  2020-02-01            1          0
# IND                Asia          India  2020-02-02            2          1
# IND                Asia          India  2020-02-03            3          1
# ...                 ...            ...         ...          ...        ...
# USA       North America  United States  2022-02-13     77762374      56776
# USA       North America  United States  2022-02-14     77925899     163525
# USA       North America  United States  2022-02-15     78036352     110453
# USA       North America  United States  2022-02-16     78172840     136488
# USA       North America  United States  2022-02-17     78269443      96603
#
#           new_deaths  year month
# iso_code
# ...

# %%
dn.loc[dn['location'].str.contains(r'thai|state|kingdom$|india', case=False)]
# .sum(axis=1)
# Out:
#               continent       location        date  total_cases  new_cases  \
# iso_code
# IND                Asia          India  2020-01-30            1          1
# IND                Asia          India  2020-01-31            1          0
# IND                Asia          India  2020-02-01            1          0
# IND                Asia          India  2020-02-02            2          1
# IND                Asia          India  2020-02-03            3          1
# ...                 ...            ...         ...          ...        ...
# USA       North America  United States  2022-02-13     77762374      56776
# USA       North America  United States  2022-02-14     77925899     163525
# USA       North America  United States  2022-02-15     78036352     110453
# USA       North America  United States  2022-02-16     78172840     136488
# USA       North America  United States  2022-02-17     78269443      96603
#
#           new_deaths  year month
# iso_code
# ...

# %%
dn['quarter'] = dn['date'].dt.quarter
dn[['date', 'quarter']].sample(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14456/2057962397.py in <module>
# ----> 1 dn['quarter'] = dn['date'].dt.quarter
#       2 dn[['date', 'quarter']].sample(5)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
pd.period_range(start='2020-01-01', end='2020-12-31', freq='M')

# %%
dn.info()

# %%
dn['date'] = pd.to_datetime(dn['date'])

# %%
dn.info()

# %%
pd.date_range(start='1/1/2020', periods=26, freq='M')
